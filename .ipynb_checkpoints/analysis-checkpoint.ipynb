# %% [markdown]
# ## DICA: VISUALIZAR TODAS AS DISTRUIÇÕES COMO EVENTOS DE POISSION

# %% [markdown]
# ## DICA:
# #### DIVIDIR ANÁLISE EM 4 CATEGORIAS EXPONENCIALS/POISSION:
# - DURAÇÃO CADA GRUPO DE MENSAGENS DE UM USUÁRIO
# - TEMPO ENTRE GRUPOS DE MENSAGENS DE UM USUÁRIO
# - DURAÇÃO CADA CONVERSA (clusters de conversas)
# - TEMPO ENTRE CONVERSAS (clusters de conversas)
# - DURAÇÃO CADA CONVERSA DIÁRIA (clusters diarios)
# - TEMPO ENTRE CONVERSAS DIÁRIAS (clusters diarios)
# - TEMPO INÍCIO CONVERSA DIÁRIA A PARTIR DE MEIA NOITE (clusters diarios)
# - TEMPO FIM CONVERSA DIÁRIA A PARTIR DE MEIA NOITE (clusters diarios)
#
# #### Para cada uma:
# - Modelar exponencial, poisson e projeção

# %% [markdown]
# #### Load data

# %%
import pandas as pd

df = pd.read_csv('chat.csv')

display(df.head())
# Out:
#              timestamp   user  \
# 0  2023-08-09 16:57:00    NaN
# 1  2023-07-19 14:34:00   Luis
# 2  2023-07-19 14:26:00  hanna
# 3  2023-07-19 14:46:00   Luis
# 4  2023-07-19 14:46:00   Luis
#
#                                                 text        date      time
# 0  As mensagens e as ligações são protegidas com ...  2023-08-09  16:57:00
# 1                                Aguardando mensagem  2023-07-19  14:34:00
# 2                                Aguardando mensagem  2023-07-19  14:26:00
# 3                                Aguardando mensagem  2023-07-19  14:46:00
# 4                                Aguardando mensagem  2023-07-19  14:46:00

# %% [markdown]
# #### Clean data

# %%
# Drop missing values for user
df = df.dropna(subset=['user'])

# Convert timestamps to datetime
df.loc[:, 'timestamp'] = pd.to_datetime(df['timestamp'])

# Display timestamps
display(df['timestamp'])
# Out:
# 1        2023-07-19 14:34:00
# 2        2023-07-19 14:26:00
# 3        2023-07-19 14:46:00
# 4        2023-07-19 14:46:00
# 5        2023-07-19 14:46:00
#                 ...
# 52454    2024-05-08 18:02:00
# 52455    2024-05-08 18:03:00
# 52456    2024-05-08 18:03:00
# 52457    2024-05-08 18:03:00
# 52458    2024-05-08 18:20:00
# Name: timestamp, Length: 51997, dtype: object

# %% [markdown]
# ---
# # Feature Engineering

# %% [markdown]
# ## Time to reply

# %%
prev_row = df.iloc[0]

data = []
for idx, row in df.iterrows():    
    user = row['user']
    timestamp = row['timestamp']

    prev_user = prev_row['user']
    prev_timestamp = prev_row['timestamp']

    if user != prev_user:
        timedelta = timestamp - prev_timestamp
        new_row = {
            'index': idx,
            'user': user,
            'timestamp': timestamp,
            'prev_user': prev_user,
            'prev_timestamp': prev_timestamp,
            'timedelta': timedelta,
            'seconds': timedelta.seconds,
            'minutes': timedelta.seconds / 60,
        }
        data.append(new_row)
    prev_row = row
    
reply = pd.DataFrame(data)
reply = reply.iloc[1:].reset_index(drop=True) # Drop first row

reply.head(5)
# Out:
#    index   user           timestamp prev_user      prev_timestamp  \
# 0      3   Luis 2023-07-19 14:46:00     hanna 2023-07-19 14:26:00
# 1      6  hanna 2023-07-19 14:47:00      Luis 2023-07-19 14:46:00
# 2      7   Luis 2023-07-19 14:48:00     hanna 2023-07-19 14:47:00
# 3      8  hanna 2023-07-19 14:51:00      Luis 2023-07-19 14:48:00
# 4      9   Luis 2023-07-19 14:53:00     hanna 2023-07-19 14:51:00
#
#         timedelta  seconds  minutes
# 0 0 days 00:20:00     1200     20.0
# 1 0 days 00:01:00       60      1.0
# 2 0 days 00:01:00       60      1.0
# 3 0 days 00:03:00      180      3.0
# 4 0 days 00:02:00      120      2.0

# %% [markdown]
# ## Time between first and last messages of a reply

# %%
prev_row = df.iloc[0]

data = []
reply_msgs = []
for idx, row in df.iterrows():    
    user = row['user']
    timestamp = row['timestamp']

    prev_user = prev_row['user']
    prev_timestamp = prev_row['timestamp']

    if user != prev_user:
        timestamp_start = reply_msgs[0]['timestamp']
        timestamp_end = reply_msgs[-1]['timestamp']
        timedelta = timestamp_end - timestamp_start
        new_row = {
            'index': idx,
            'user': prev_user,
            'prev_user': user,
            'messages': len(reply_msgs),
            'start': timestamp_start,
            'end': timestamp_end,
            'timedelta': timedelta,
            'seconds': timedelta.seconds,
            'minutes': timedelta.seconds / 60,
        }
        data.append(new_row)
        reply_msgs = []
        
    reply_msgs.append(row.to_dict())
    prev_row = row
    
replying = pd.DataFrame(data)
# replying = replying.iloc[1:].reset_index(drop=True) # Drop first row

replying.head(5)
# Out:
#    index   user prev_user  messages               start                 end  \
# 0      2   Luis     hanna         1 2023-07-19 14:34:00 2023-07-19 14:34:00
# 1      3  hanna      Luis         1 2023-07-19 14:26:00 2023-07-19 14:26:00
# 2      6   Luis     hanna         3 2023-07-19 14:46:00 2023-07-19 14:46:00
# 3      7  hanna      Luis         1 2023-07-19 14:47:00 2023-07-19 14:47:00
# 4      8   Luis     hanna         1 2023-07-19 14:48:00 2023-07-19 14:48:00
#
#   timedelta  seconds  minutes
# 0    0 days        0      0.0
# 1    0 days        0      0.0
# 2    0 days        0      0.0
# 3    0 days        0      0.0
# 4    0 days        0      0.0

# %% [markdown]
# ## Time between blobs of messages

# %% [markdown]
# #### Parse time between messages in seconds (min-max normalized)

# %%
df['uuid'] = df['timestamp'].apply(lambda d: d.value)
df['uuid'] = (df['uuid'] - df['uuid'].min()) / (df['uuid'].max() - df['uuid'].min()) # Min-Max Scaling

df['uuid']
# Out:
# 1        0.000019
# 2        0.000000
# 3        0.000047
# 4        0.000047
# 5        0.000047
#            ...
# 52454    0.999958
# 52455    0.999960
# 52456    0.999960
# 52457    0.999960
# 52458    1.000000
# Name: uuid, Length: 51997, dtype: float64

# %% [markdown]
# #### Build chat talks from cluster labels

# %%
meanshift_df = pd.read_csv('meanshift_pred_0-0000727281.csv', index_col=0)

df['label'] = meanshift_df['label'].loc[df.index]

prev_row = df.iloc[0]

data = []
talk_msgs = []
for idx, row in df.iterrows():
    label = row['label']
    user = row['user']
    timestamp = row['timestamp']

    prev_label = prev_row['label']
    prev_user = prev_row['user']
    prev_timestamp = prev_row['timestamp']

    if label != prev_label:
        timestamp_start = talk_msgs[0]['timestamp']
        timestamp_end = talk_msgs[-1]['timestamp']
        timedelta = timestamp_end - timestamp_start
        new_row = {
            'index': idx,
            'label': prev_label,
            'user': prev_user,
            'prev_user': user,
            'messages': len(talk_msgs),
            'start': timestamp_start,
            'end': timestamp_end,
            'timedelta': timedelta,
            'seconds': timedelta.seconds,
            'minutes': timedelta.seconds / 60,
        }
        data.append(new_row)
        talk_msgs = []
        
    talk_msgs.append(row.to_dict())
    prev_row = row
    
talks = pd.DataFrame(data)

print('Number of clusters:', len(talks))
talks.head(5)
# Out:
#    index  label   user prev_user  messages               start  \
# 0     27    827  hanna      Luis        26 2023-07-19 14:34:00
# 1     41    982   Luis     hanna        14 2023-07-19 19:30:00
# 2     74    527  hanna      Luis        33 2023-07-19 20:16:00
# 3     83   1472  hanna     hanna         9 2023-07-19 21:47:00
# 4     86   1981  hanna      Luis         3 2023-07-19 22:43:00
#
#                   end       timedelta  seconds  minutes
# 0 2023-07-19 15:56:00 0 days 01:22:00     4920     82.0
# 1 2023-07-19 19:49:00 0 days 00:19:00     1140     19.0
# 2 2023-07-19 20:49:00 0 days 00:33:00     1980     33.0
# 3 2023-07-19 22:06:00 0 days 00:19:00     1140     19.0
# 4 2023-07-19 22:44:00 0 days 00:01:00       60      1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

plt.figure(figsize=(10, 6))
labels = df['label']
unique_labels = talks['label']
# unique_labels = np.unique(labels)
# colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, 20)]
np.random.seed(12345)
colors = list(np.random.permutation(colors))
colors = colors * 150

for k, col in zip(unique_labels, colors):
    class_member_mask = (labels == k)
    xy = df[['uuid']][class_member_mask]
    plt.plot(xy, np.zeros_like(xy), 'o', markerfacecolor=tuple(col), markeredgecolor='k', markersize=6)

plt.xlim((0.002, 0.005))
plt.title('MeanShift Clustering with Optimized Bandwidth (selected Score)')
plt.show()

# %% [markdown]
# ---
# # Mathematical Models

# %% [markdown]
# ### DICA: ARREDONDAR DISTRIBUIÇÕES EXPONENCIALS COM MÉDIAS MENORES E COMPARAR COM O HISTOGRAMA DESTA DISTRUIBÇÃO ACIMA

# %% [markdown]
# ## Time between first and last messages of a reply

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

y_min = 0
y_max = 25
user_replying = replying[replying['user'] == 'Luis']
user_replying_cut = user_replying[(user_replying['minutes'] >= y_min) & (user_replying['minutes'] <= y_max)]

# Generate exponentially distributed values
values = user_replying_cut['minutes'].values
lambda_param = 1 / np.mean(values)

# Histogram
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.hist(values, bins=30, density=True, alpha=0.6, color='g')

# Theoretical probability density function
x = np.linspace(0, np.max(values), 100)
pdf = lambda_param * np.exp(-lambda_param * x)
plt.plot(x, pdf, 'r', linewidth=2)

# Titles and labels
plt.title('Histogram and Probability Plot')
plt.xlabel('Value')
plt.ylabel('Density')

# Q-Q Plot
plt.subplot(1, 2, 2)
stats.probplot(values, dist="expon", sparams=(0, 1/lambda_param), plot=plt)
plt.title("Q-Q Plot for Exponential Distribution")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Time to reply

# %%
import numpy as np

y_min = 6
y_max = 160
cut_memory = True

bins = np.arange(-1.5, y_max, 1)

user_0 = reply[reply['user'] == 'Luis']
user_values = user_0[user_0['minutes'] >= y_min]['minutes']
if cut_memory:
    user_values = user_values[user_0['minutes'] <= y_max + y_min]
    user_values -= y_min
else:
    user_values = user_values[user_0['minutes'] <= y_max]
    
user_values_cnt = user_values.value_counts(normalize=True).sort_index()


user_lambda = user_values.mean()
user_n_values = len(user_values)

rs = 12345
lambda_ = user_lambda
n_values = user_n_values
# n_values = 5000

np.random.seed(rs)
values = np.random.exponential(lambda_, n_values)
values_1 = np.random.exponential(lambda_ + 1, n_values)
values_2 = np.random.exponential(lambda_ + 2, n_values)
values_3 = np.random.exponential(lambda_ + 3, n_values)
values_cnt = pd.Series(values).round(0).value_counts(normalize=True).sort_index()
values_1_cnt = pd.Series(values_1).round(0).value_counts(normalize=True).sort_index()
values_2_cnt = pd.Series(values_2).round(0).value_counts(normalize=True).sort_index()
values_3_cnt = pd.Series(values_3).round(0).value_counts(normalize=True).sort_index()

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# Plot user histogram
# plt.hist(user_values.values, bins=bins, density=True, alpha=0.4, color='b', label=f'reply time (after {y_min} min)')
plt.bar(user_values_cnt.index, user_values_cnt.values, alpha=0.6, color='b', label=f'reply time (after {y_min} min)')
plt.plot(user_values_cnt.index, user_values_cnt.values, alpha=0.6, color='b', label=f'reply time (after {y_min} min)')

# Plot histogram
# plt.hist(values, bins=bins, density=True, alpha=0.4, color='g')
# plt.hist(values_2, bins=bins, density=True, alpha=0.6, color='orange')
# plt.bar(values_cnt.index, values_cnt, alpha=0.4, color='g')
values_cnt.plot(alpha=0.6, color='g', label=f'exp (lambda={round(user_lambda, 2)})')
# values_1_cnt.plot(alpha=0.6, color='y', label='-1')
# values_2_cnt.plot(alpha=0.6, color='orange', label='-2')
values_3_cnt.plot(alpha=0.6, color='r', label=f'exp (lambda={round(user_lambda, 2)} + 3)')

# Add titles and labels
plt.title('Histogram of Exponentially Distributed Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.xlim(-4, y_max)


# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate exponentially distributed values
# np.random.seed(42)
lambda_param = 1 / user_lambda
# values = np.random.exponential(1/lambda_param, 1000)

# Histogram
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.hist(user_values, bins=30, density=True, alpha=0.6, color='g')

# Theoretical probability density function
x = np.linspace(0, np.max(user_values), 100)
pdf = lambda_param * np.exp(-lambda_param * x)
plt.plot(x, pdf, 'r', linewidth=2)

# Titles and labels
plt.title('Histogram and Probability Plot')
plt.xlabel('Value')
plt.ylabel('Density')

# Q-Q Plot
plt.subplot(1, 2, 2)
stats.probplot(user_values, dist="expon", sparams=(0, 1/lambda_param), plot=plt)
plt.title("Q-Q Plot for Exponential Distribution")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Test exponential distribution

# %% [markdown]
# ## Testing exponential distribution for set of values

# %%
from scipy.stats import kstest, expon

# values = user_values
values = pd.Series(user_values).sample(100)

# Perform the K-S test
D, p_value = kstest(values, 'expon', args=(0, 1/lambda_param))
print(f"K-S Test Statistic: {D}")
print(f"P-value: {p_value}")
# Out:
# K-S Test Statistic: 0.7768698398515702
# P-value: 3.3287736319878196e-64

# %%
from scipy.stats import anderson

# Perform the Anderson-Darling test
result = anderson(values, dist='expon')
print(f"Anderson-Darling Test Statistic: {result.statistic}")
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    print(f"Significance level: {sl:.2f}, Critical value: {cv:.3f}")
    if result.statistic < cv:
        print("The data follows the exponential distribution for this significance level.")
    else:
        print("The data does not follow the exponential distribution for this significance level.")
# Out:
# Anderson-Darling Test Statistic: 3.789593697091348
# Significance level: 15.00, Critical value: 0.917
# The data does not follow the exponential distribution for this significance level.
# Significance level: 10.00, Critical value: 1.072
# The data does not follow the exponential distribution for this significance level.
# Significance level: 5.00, Critical value: 1.333
# The data does not follow the exponential distribution for this significance level.
# Significance level: 2.50, Critical value: 1.596
# The data does not follow the exponential distribution for this significance level.
# Significance level: 1.00, Critical value: 1.945
# The data does not follow the exponential distribution for this significance level.

# %%
from scipy.stats import chisquare

# Number of bins
num_bins = 30

# Observed frequencies
observed_freq, bins = np.histogram(values, bins=num_bins)

# Expected frequencies
expected_freq = len(values) * (expon.cdf(bins[1:], scale=1/lambda_param) - expon.cdf(bins[:-1], scale=1/lambda_param))

# Adjust expected frequencies to match the sum of observed frequencies
expected_freq *= observed_freq.sum() / expected_freq.sum()

# Perform the Chi-Square test
chi2_stat, p_val = chisquare(observed_freq, f_exp=expected_freq)
print(f"Chi-Square Test Statistic: {chi2_stat}")
print(f"P-value: {p_val}")
# Out:
# Chi-Square Test Statistic: 248452801.493633
# P-value: 0.0

# %%
import numpy as np

# Generate exponentially distributed values
# np.random.seed(42)
# lambda_param = 1.5
# values = np.random.exponential(1/lambda_param, 1000)

# Perform MLE for the rate parameter lambda
sample_mean = np.mean(values)
mle_lambda = 1 / sample_mean

print(f"Sample Mean: {sample_mean}")
print(f"MLE for lambda: {mle_lambda}")
# Out:
# Sample Mean: 3.93
# MLE for lambda: 0.2544529262086514
